# %%
import pandas as pd 
import matplotlib as plt
from matplotlib import pyplot as plt
df= pd.read_csv('district_wise.csv')

# %%
import matplotlib.pyplot as plt
count=["confirmed","recoverd","active","deaths"]
numbers=[13189,9554,3528,107]
plt.plot(count,numbers)
plt.title("status of Bihar")
plt.ylabel("y axis")
plt.xlabel("x axis")
plt.show()

# %%
data_bihar=df.loc[df['State'] == "Bihar"]

# %%
data_bihar.head(15)
# Out:
#     SlNo State_Code  State       District_Key        District  Confirmed  \
# 79    75         BR  Bihar          BR_Araria          Araria        157
# 80    76         BR  Bihar           BR_Arwal           Arwal        144
# 81    77         BR  Bihar      BR_Aurangabad      Aurangabad        301
# 82    78         BR  Bihar           BR_Banka           Banka        282
# 83    79         BR  Bihar       BR_Begusarai       Begusarai        639
# 84    80         BR  Bihar       BR_Bhagalpur       Bhagalpur        756
# 85    81         BR  Bihar         BR_Bhojpur         Bhojpur        292
# 86    82         BR  Bihar           BR_Buxar           Buxar        269
# 87    83         BR  Bihar       BR_Darbhanga       Darbhanga        396
# 88   101         BR  Bihar  BR_East Champaran  East Champaran        290
# 89    84         BR  Bihar            BR_Gaya            Gaya        331
# 90    85         BR  Bihar       BR_Gopalganj       Gopalganj        396
# ...

# %%
data_bihar.tail(15)
# Out:
#      SlNo State_Code  State       District_Key        District  Confirmed  \
# 103    98         BR  Bihar          BR_Nawada          Nawada        414
# 104   100         BR  Bihar           BR_Patna           Patna       1485
# 105   102         BR  Bihar          BR_Purnia          Purnia        343
# 106   103         BR  Bihar          BR_Rohtas          Rohtas        405
# 107   104         BR  Bihar         BR_Saharsa         Saharsa        276
# 108   105         BR  Bihar      BR_Samastipur      Samastipur        406
# 109   106         BR  Bihar           BR_Saran           Saran        301
# 110   107         BR  Bihar      BR_Sheikhpura      Sheikhpura        188
# 111   108         BR  Bihar         BR_Sheohar         Sheohar        106
# 112   109         BR  Bihar       BR_Sitamarhi       Sitamarhi        168
# 113   110         BR  Bihar           BR_Siwan           Siwan        547
# 114   111         BR  Bihar          BR_Supaul          Supaul        326
# ...

# %%
data_bihar.describe()
# Out:
#              SlNo    Confirmed      Active   Recovered   Deceased  \
# count   39.000000    39.000000   39.000000   39.000000  39.000000
# mean   109.871795   358.410256  104.538462  251.076923   2.794872
# std    102.828211   240.554701  131.599641  125.383073   2.764241
# min     75.000000     0.000000    0.000000    0.000000   0.000000
# 25%     84.500000   233.500000   43.000000  179.500000   1.000000
# 50%     94.000000   322.000000   72.000000  232.000000   2.000000
# 75%    103.500000   405.500000  127.000000  312.500000   4.500000
# max    732.000000  1485.000000  830.000000  642.000000  13.000000
#
#        Migrated_Other  Delta_Confirmed  Delta_Active  Delta_Recovered  \
# count            39.0        39.000000     39.000000        39.000000
# mean              0.0        18.051282     11.384615         6.435897
# std               0.0        25.806924     24.832720        10.156136
# min               0.0         0.000000    -23.000000         0.000000
# ...

# %%
import matplotlib.pyplot as plt
count=["confirmed","recovered","active","death"]
numbers=[31156,20331,9980,845]
plt.plot(count,numbers)
plt.title("status_of_uttar pradesh_COVID19")
plt.ylabel("y axis")
plt.xlabel("x axis")
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')

x=["confirmed","recovered","active","death"]
y=[13189,9554,3528,107]
x2=["confirmed","recovered","active","death"]
y2=[31156,20331,9980,845]
plt.plot(x,y,'g',label='Bihar',linewidth=5)
plt.plot(x2,y2,'c',label='uttar pradesh',linewidth=5)
plt.plot(count,numbers)
plt.title("status of Bihar and uttar pradesh COVID19")
plt.ylabel("y axis")
plt.xlabel("x axis")
plt.grid(True,color='k')
plt.legend()
plt.show()
